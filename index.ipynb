# %% [markdown]
# # Exploring and Transforming JSON Schemas

# %% [markdown]
# # Introduction
#
# In this lesson, you'll formalize how to explore a JSON file whose structure and schema is unknown to you. This often happens in practice when you are handed a file or stumble upon one with little documentation.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Explore unknown JSON schemas
# * Access and manipulate data inside a JSON file
# * Convert JSON to alternative data formats

# %% [markdown]
# ## Loading the JSON file
#
# Load the data from the file disease_data.json.

# %%
import json

# %%
import pandas as pd

# %%
#Your code here
f = open('disease_data.json')
data = json.load(f)

# %% [markdown]
# ## Explore the first and second levels of the schema hierarchy

# %%
#Your code here
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['meta', 'data'])

# %%
type(data['meta'])
# Out:
# dict

# %%
type(data['data'])
# Out:
# list

# %%
data['meta'].keys()
# Out:
# dict_keys(['view'])

# %%
data['meta']['view'].keys()
# Out:
# dict_keys(['id', 'name', 'attribution', 'attributionLink', 'averageRating', 'category', 'createdAt', 'description', 'displayType', 'downloadCount', 'hideFromCatalog', 'hideFromDataJson', 'indexUpdatedAt', 'licenseId', 'newBackend', 'numberOfComments', 'oid', 'provenance', 'publicationAppendEnabled', 'publicationDate', 'publicationGroup', 'publicationStage', 'rowClass', 'rowsUpdatedAt', 'rowsUpdatedBy', 'tableId', 'totalTimesRated', 'viewCount', 'viewLastModified', 'viewType', 'columns', 'grants', 'license', 'metadata', 'owner', 'query', 'rights', 'tableAuthor', 'tags', 'flags'])

# %%
data['meta']['view']['columns'][0]
# Out:
# {'id': -1,
#  'name': 'sid',
#  'dataTypeName': 'meta_data',
#  'fieldName': ':sid',
#  'position': 0,
#  'renderTypeName': 'meta_data',
#  'format': {},
#  'flags': ['hidden']}

# %%
len(data['meta']['view']['columns'])
# Out:
# 42

# %%
col_names = [data['meta']['view']['columns'][n]['name'] for n in range(0,42)]

# %%
len(list(data['meta']['view'].keys()))
# Out:
# 40

# %%
len(data['data'])
# Out:
# 60266

# %% [markdown]
# ## Convert to a DataFrame
#
# Create a DataFrame from the JSON file. Be sure to retrive the column names for the dataframe. (Search within the 'meta' key of the master dictionary.) The DataFrame should include all 42 columns.

# %%
#Your code here
df = pd.DataFrame.from_records(data['data'], columns=col_names)
df.head().T
# Out:
#                                                                            0  \
# sid                                                                        1
# id                                      FF49C41F-CE8D-46C4-9164-653B1227CF6F
# position                                                                   1
# created_at                                                        1527194521
# created_meta                                                          959778
# updated_at                                                        1527194521
# updated_meta                                                          959778
# meta                                                                    None
# YearStart                                                               2016
# YearEnd                                                                 2016
# LocationAbbr                                                              US
# LocationDesc                                                   United States
# DataSource                                                             BRFSS
# Topic                                                                Alcohol
# Question                   Binge drinking prevalence among adults aged >=...
# Response                                                                None
# DataValueUnit                                                              %
# DataValueType                                               Crude Prevalence
# DataValue                                                               16.9
# DataValueAlt                                                            16.9
# DataValueFootnoteSymbol                                                    *
# DatavalueFootnote                                  50 States + DC: US Median
# LowConfidenceLimit                                                        16
# HighConfidenceLimit                                                       18
# StratificationCategory1                                              Overall
# Stratification1                                                      Overall
# StratificationCategory2                                                 None
# Stratification2                                                         None
# StratificationCategory3                                                 None
# Stratification3                                                         None
# GeoLocation                                   [None, None, None, None, None]
# ResponseID                                                              None
# LocationID                                                                59
# TopicID                                                                  ALC
# QuestionID                                                            ALC2_2
# DataValueTypeID                                                      CRDPREV
# StratificationCategoryID1                                            OVERALL
# StratificationID1                                                        OVR
# StratificationCategoryID2                                               None
# StratificationID2                                                       None
# StratificationCategoryID3                                               None
# StratificationID3                                                       None
#
#                                                                            1  \
# sid                                                                        2
# id                                      F4468C3D-340A-4CD2-84A3-DF554DFF065E
# position                                                                   2
# created_at                                                        1527194521
# created_meta                                                          959778
# updated_at                                                        1527194521
# updated_meta                                                          959778
# meta                                                                    None
# YearStart                                                               2016
# YearEnd                                                                 2016
# LocationAbbr                                                              AL
# LocationDesc                                                         Alabama
# DataSource                                                             BRFSS
# Topic                                                                Alcohol
# Question                   Binge drinking prevalence among adults aged >=...
# Response                                                                None
# DataValueUnit                                                              %
# DataValueType                                               Crude Prevalence
# DataValue                                                                 13
# DataValueAlt                                                              13
# DataValueFootnoteSymbol                                                 None
# DatavalueFootnote                                                       None
# LowConfidenceLimit                                                      11.9
# HighConfidenceLimit                                                     14.1
# StratificationCategory1                                              Overall
# Stratification1                                                      Overall
# StratificationCategory2                                                 None
# Stratification2                                                         None
# StratificationCategory3                                                 None
# Stratification3                                                         None
# GeoLocation                [None, 32.84057112200048, -86.63186076199969, ...
# ResponseID                                                              None
# LocationID                                                                01
# TopicID                                                                  ALC
# QuestionID                                                            ALC2_2
# DataValueTypeID                                                      CRDPREV
# StratificationCategoryID1                                            OVERALL
# StratificationID1                                                        OVR
# StratificationCategoryID2                                               None
# StratificationID2                                                       None
# StratificationCategoryID3                                               None
# StratificationID3                                                       None
#
#                                                                            2  \
# sid                                                                        3
# id                                      65609156-A343-4869-B03F-2BA62E96AC19
# position                                                                   3
# created_at                                                        1527194521
# created_meta                                                          959778
# updated_at                                                        1527194521
# updated_meta                                                          959778
# meta                                                                    None
# YearStart                                                               2016
# YearEnd                                                                 2016
# LocationAbbr                                                              AK
# LocationDesc                                                          Alaska
# DataSource                                                             BRFSS
# Topic                                                                Alcohol
# Question                   Binge drinking prevalence among adults aged >=...
# Response                                                                None
# DataValueUnit                                                              %
# DataValueType                                               Crude Prevalence
# DataValue                                                               18.2
# DataValueAlt                                                            18.2
# DataValueFootnoteSymbol                                                 None
# DatavalueFootnote                                                       None
# LowConfidenceLimit                                                        16
# HighConfidenceLimit                                                     20.6
# StratificationCategory1                                              Overall
# Stratification1                                                      Overall
# StratificationCategory2                                                 None
# Stratification2                                                         None
# StratificationCategory3                                                 None
# Stratification3                                                         None
# GeoLocation                [None, 64.84507995700051, -147.72205903599973,...
# ResponseID                                                              None
# LocationID                                                                02
# TopicID                                                                  ALC
# QuestionID                                                            ALC2_2
# DataValueTypeID                                                      CRDPREV
# StratificationCategoryID1                                            OVERALL
# StratificationID1                                                        OVR
# StratificationCategoryID2                                               None
# StratificationID2                                                       None
# StratificationCategoryID3                                               None
# StratificationID3                                                       None
#
#                                                                            3  \
# sid                                                                        4
# id                                      0DB09B00-EFEB-4AC0-9467-A7CBD2B57BF3
# position                                                                   4
# created_at                                                        1527194521
# created_meta                                                          959778
# updated_at                                                        1527194521
# updated_meta                                                          959778
# meta                                                                    None
# YearStart                                                               2016
# YearEnd                                                                 2016
# LocationAbbr                                                              AZ
# LocationDesc                                                         Arizona
# DataSource                                                             BRFSS
# Topic                                                                Alcohol
# Question                   Binge drinking prevalence among adults aged >=...
# Response                                                                None
# DataValueUnit                                                              %
# DataValueType                                               Crude Prevalence
# DataValue                                                               15.6
# DataValueAlt                                                            15.6
# DataValueFootnoteSymbol                                                 None
# DatavalueFootnote                                                       None
# LowConfidenceLimit                                                      14.3
# HighConfidenceLimit                                                     16.9
# StratificationCategory1                                              Overall
# Stratification1                                                      Overall
# StratificationCategory2                                                 None
# Stratification2                                                         None
# StratificationCategory3                                                 None
# Stratification3                                                         None
# GeoLocation                [None, 34.865970280000454, -111.76381127699972...
# ResponseID                                                              None
# LocationID                                                                04
# TopicID                                                                  ALC
# QuestionID                                                            ALC2_2
# DataValueTypeID                                                      CRDPREV
# StratificationCategoryID1                                            OVERALL
# StratificationID1                                                        OVR
# StratificationCategoryID2                                               None
# StratificationID2                                                       None
# StratificationCategoryID3                                               None
# StratificationID3                                                       None
#
#                                                                            4
# sid                                                                        5
# id                                      D98DA5BA-6FD6-40F5-A9B1-ABD45E44967B
# position                                                                   5
# created_at                                                        1527194521
# created_meta                                                          959778
# updated_at                                                        1527194521
# updated_meta                                                          959778
# meta                                                                    None
# YearStart                                                               2016
# YearEnd                                                                 2016
# LocationAbbr                                                              AR
# LocationDesc                                                        Arkansas
# DataSource                                                             BRFSS
# Topic                                                                Alcohol
# Question                   Binge drinking prevalence among adults aged >=...
# Response                                                                None
# DataValueUnit                                                              %
# DataValueType                                               Crude Prevalence
# DataValue                                                                 15
# DataValueAlt                                                              15
# DataValueFootnoteSymbol                                                 None
# DatavalueFootnote                                                       None
# LowConfidenceLimit                                                        13
# HighConfidenceLimit                                                     17.2
# StratificationCategory1                                              Overall
# Stratification1                                                      Overall
# StratificationCategory2                                                 None
# Stratification2                                                         None
# StratificationCategory3                                                 None
# Stratification3                                                         None
# GeoLocation                [None, 34.74865012400045, -92.27449074299966, ...
# ResponseID                                                              None
# LocationID                                                                05
# TopicID                                                                  ALC
# QuestionID                                                            ALC2_2
# DataValueTypeID                                                      CRDPREV
# StratificationCategoryID1                                            OVERALL
# StratificationID1                                                        OVR
# StratificationCategoryID2                                               None
# StratificationID2                                                       None
# StratificationCategoryID3                                               None
# StratificationID3                                                       None

# %% [markdown]
# ## Level-Up
# ## Create a bar graph of states with the highest asthma rates for adults age 18+

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_asthma = df.loc[df['Question'] == 
                  'Current asthma prevalence among adults aged >= 18 years']

# %%
df_asthma = df_asthma.loc[df_asthma['StratificationCategory1'] == 'Overall']

# %%
df_asthma = df_asthma.loc[df['DataValueType']=='Age-adjusted Prevalence']

# %%
df_asthma['DataValue'] = df_asthma['DataValue'].apply(float)

# %%
df_asthma = df_asthma.sort_values(by='DataValue')

# %%
df_asthma.head().T
# Out:
#                                                                         9477  \
# sid                                                                     9475
# id                                      AD9F3280-58FC-430D-8A0B-DD5B2159DE30
# position                                                                9475
# created_at                                                        1527194523
# created_meta                                                          959778
# updated_at                                                        1527194523
# updated_meta                                                          959778
# meta                                                                    None
# YearStart                                                               2016
# YearEnd                                                                 2016
# LocationAbbr                                                              GU
# LocationDesc                                                            Guam
# DataSource                                                             BRFSS
# Topic                                                                 Asthma
# Question                   Current asthma prevalence among adults aged >=...
# Response                                                                None
# DataValueUnit                                                              %
# DataValueType                                        Age-adjusted Prevalence
# DataValue                                                                5.6
# DataValueAlt                                                             5.6
# DataValueFootnoteSymbol                                                 None
# DatavalueFootnote                                                       None
# LowConfidenceLimit                                                         4
# HighConfidenceLimit                                                      7.7
# StratificationCategory1                                              Overall
# Stratification1                                                      Overall
# StratificationCategory2                                                 None
# Stratification2                                                         None
# StratificationCategory3                                                 None
# Stratification3                                                         None
# GeoLocation                       [None, 13.444304, 144.793731, None, False]
# ResponseID                                                              None
# LocationID                                                                66
# TopicID                                                                  AST
# QuestionID                                                            AST1_1
# DataValueTypeID                                                   AGEADJPREV
# StratificationCategoryID1                                            OVERALL
# StratificationID1                                                        OVR
# StratificationCategoryID2                                               None
# StratificationID2                                                       None
# StratificationCategoryID3                                               None
# StratificationID3                                                       None
#
#                                                                         9467  \
# sid                                                                     9465
# id                                      E5084FC1-81E5-40FB-9D8C-5E7D4D27206C
# position                                                                9465
# created_at                                                        1527194523
# created_meta                                                          959778
# updated_at                                                        1527194523
# updated_meta                                                          959778
# meta                                                                    None
# YearStart                                                               2016
# YearEnd                                                                 2016
# LocationAbbr                                                              SD
# LocationDesc                                                    South Dakota
# DataSource                                                             BRFSS
# Topic                                                                 Asthma
# Question                   Current asthma prevalence among adults aged >=...
# Response                                                                None
# DataValueUnit                                                              %
# DataValueType                                        Age-adjusted Prevalence
# DataValue                                                                  6
# DataValueAlt                                                               6
# DataValueFootnoteSymbol                                                 None
# DatavalueFootnote                                                       None
# LowConfidenceLimit                                                         5
# HighConfidenceLimit                                                      7.1
# StratificationCategory1                                              Overall
# Stratification1                                                      Overall
# StratificationCategory2                                                 None
# Stratification2                                                         None
# StratificationCategory3                                                 None
# Stratification3                                                         None
# GeoLocation                [None, 44.353130053000484, -100.3735306369997,...
# ResponseID                                                              None
# LocationID                                                                46
# TopicID                                                                  AST
# QuestionID                                                            AST1_1
# DataValueTypeID                                                   AGEADJPREV
# StratificationCategoryID1                                            OVERALL
# StratificationID1                                                        OVR
# StratificationCategoryID2                                               None
# StratificationID2                                                       None
# StratificationCategoryID3                                               None
# StratificationID3                                                       None
#
#                                                                         9479  \
# sid                                                                     9477
# id                                      605A37E7-FA17-4D41-AEF1-367AF95BC7DA
# position                                                                9477
# created_at                                                        1527194523
# created_meta                                                          959778
# updated_at                                                        1527194523
# updated_meta                                                          959778
# meta                                                                    None
# YearStart                                                               2016
# YearEnd                                                                 2016
# LocationAbbr                                                              VI
# LocationDesc                                                  Virgin Islands
# DataSource                                                             BRFSS
# Topic                                                                 Asthma
# Question                   Current asthma prevalence among adults aged >=...
# Response                                                                None
# DataValueUnit                                                              %
# DataValueType                                        Age-adjusted Prevalence
# DataValue                                                                6.6
# DataValueAlt                                                             6.6
# DataValueFootnoteSymbol                                                 None
# DatavalueFootnote                                                       None
# LowConfidenceLimit                                                       4.4
# HighConfidenceLimit                                                      9.8
# StratificationCategory1                                              Overall
# Stratification1                                                      Overall
# StratificationCategory2                                                 None
# Stratification2                                                         None
# StratificationCategory3                                                 None
# Stratification3                                                         None
# GeoLocation                       [None, 18.335765, -64.896335, None, False]
# ResponseID                                                              None
# LocationID                                                                78
# TopicID                                                                  AST
# QuestionID                                                            AST1_1
# DataValueTypeID                                                   AGEADJPREV
# StratificationCategoryID1                                            OVERALL
# StratificationID1                                                        OVR
# StratificationCategoryID2                                               None
# StratificationID2                                                       None
# StratificationCategoryID3                                               None
# StratificationID3                                                       None
#
#                                                                         9435  \
# sid                                                                     9433
# id                                      3CD6DD98-E30E-4423-8389-1254B58C59A7
# position                                                                9433
# created_at                                                        1527194523
# created_meta                                                          959778
# updated_at                                                        1527194523
# updated_meta                                                          959778
# meta                                                                    None
# YearStart                                                               2016
# YearEnd                                                                 2016
# LocationAbbr                                                              FL
# LocationDesc                                                         Florida
# DataSource                                                             BRFSS
# Topic                                                                 Asthma
# Question                   Current asthma prevalence among adults aged >=...
# Response                                                                None
# DataValueUnit                                                              %
# DataValueType                                        Age-adjusted Prevalence
# DataValue                                                                6.7
# DataValueAlt                                                             6.7
# DataValueFootnoteSymbol                                                 None
# DatavalueFootnote                                                       None
# LowConfidenceLimit                                                       6.2
# HighConfidenceLimit                                                      7.3
# StratificationCategory1                                              Overall
# Stratification1                                                      Overall
# StratificationCategory2                                                 None
# Stratification2                                                         None
# StratificationCategory3                                                 None
# Stratification3                                                         None
# GeoLocation                [None, 28.932040377000476, -81.92896053899966,...
# ResponseID                                                              None
# LocationID                                                                12
# TopicID                                                                  AST
# QuestionID                                                            AST1_1
# DataValueTypeID                                                   AGEADJPREV
# StratificationCategoryID1                                            OVERALL
# StratificationID1                                                        OVR
# StratificationCategoryID2                                               None
# StratificationID2                                                       None
# StratificationCategoryID3                                               None
# StratificationID3                                                       None
#
#                                                                         9469
# sid                                                                     9467
# id                                      689E2756-EF46-42F2-83A3-4AF4AE44CEAC
# position                                                                9467
# created_at                                                        1527194523
# created_meta                                                          959778
# updated_at                                                        1527194523
# updated_meta                                                          959778
# meta                                                                    None
# YearStart                                                               2016
# YearEnd                                                                 2016
# LocationAbbr                                                              TX
# LocationDesc                                                           Texas
# DataSource                                                             BRFSS
# Topic                                                                 Asthma
# Question                   Current asthma prevalence among adults aged >=...
# Response                                                                None
# DataValueUnit                                                              %
# DataValueType                                        Age-adjusted Prevalence
# DataValue                                                                7.6
# DataValueAlt                                                             7.6
# DataValueFootnoteSymbol                                                 None
# DatavalueFootnote                                                       None
# LowConfidenceLimit                                                       6.7
# HighConfidenceLimit                                                      8.6
# StratificationCategory1                                              Overall
# Stratification1                                                      Overall
# StratificationCategory2                                                 None
# Stratification2                                                         None
# StratificationCategory3                                                 None
# Stratification3                                                         None
# GeoLocation                [None, 31.827240407000488, -99.42677020599967,...
# ResponseID                                                              None
# LocationID                                                                48
# TopicID                                                                  AST
# QuestionID                                                            AST1_1
# DataValueTypeID                                                   AGEADJPREV
# StratificationCategoryID1                                            OVERALL
# StratificationID1                                                        OVR
# StratificationCategoryID2                                               None
# StratificationID2                                                       None
# StratificationCategoryID3                                               None
# StratificationID3                                                       None

# %%
df_asthma.plot.bar(x='LocationAbbr', y='DataValue', figsize=(12,6))

# %% [markdown]
# ## Level-Up!
# ## Create a function (or class) that returns an outline of the schema structure like this:
# <img src="images/outline.jpg" width="350">
#
# Rules:
# * Your outline should follow the numbering outline above (I, A, 1, a, i).
# * Your outline should be properly indented! (Four spaces or one tab per indentation level.)
# * Your function goes to at least a depth of 5 (Level-up: create a parameter so that the user can specify this)
# * If an entry is a dictionary, list its keys as the subheadings
# * After listing a key name (where applicable) include a space, a dash and the data type of the entry
# * If an entry is a dict or list put in parentheses how many items are in the entry
# * lists will not have key names for their entries (they're just indexed)
# * For subheadings of a list, state their datatypes.
# * If a dictionary or list is more then 5 items long, only show the first 5 (we want to limit our previews); make an arbitrary order choice for dictionaries. (Level-up: Parallel to above; allow user to specify number of items to preview for large subheading collections.)

# %%
# Your code here; you will probably want to define subfunctions.
def print_obj_outline(json_obj):
    return outline

# %%
outline = print_obj_outline(data)

# %%
print(outline) #Your function should produce the following output for this json object (and work for all json files!)
# Out:
# I. root - <class 'dict'> (2 items)
#     A. meta <class 'dict'> (1 items)
#         1. view <class 'dict'> (40 items)
#             a. id <class 'str'>
#             b. name <class 'str'>
#             c. attribution <class 'str'>
#             d. attributionLink <class 'str'>
#             e. averageRating <class 'int'>
#     B. data <class 'list'> (60266 items)
#         1. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         2. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         3. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         4. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>
#         5. <class 'list'> (42 items)
#             a. <class 'int'>
#             b. <class 'str'>
#             c. <class 'int'>
#             d. <class 'int'>
#             e. <class 'str'>

# %% [markdown]
# ## Summary
#
# Well done! In this lab you got some extended practice exploring the structure of JSON files and writing a recursive generalized function for outlining a JSON file's schema!
